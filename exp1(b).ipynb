# %%
import sys
import pandas as pd
import numpy as np
import sklearn
import matplotlib
import seaborn as sns
print("Library Versions")
print("-" * 40)
print(f"Pandas         : {pd.__version__}")
print(f"NumPy          : {np.__version__}")
print(f"Scikit-learn   : {sklearn.__version__}")
print(f"Matplotlib     : {matplotlib.__version__}")
print(f"Seaborn        : {sns.__version__}")
# Out:
# Library Versions
# ----------------------------------------
# Pandas         : 2.2.2
# NumPy          : 2.0.2
# Scikit-learn   : 1.6.1
# Matplotlib     : 3.10.0
# Seaborn        : 0.13.2

# %%
from pandas import read_csv
df=read_csv('train.csv')

# %%
df.head(10)
# Out:
#    Student_ID  Age  Gender  Degree Branch  CGPA  Internships  Projects  \
# 0        1048   22  Female  B.Tech    ECE  6.29            0         3
# 1       37820   20  Female     BCA    ECE  6.05            1         4
# 2       49668   22    Male     MCA     ME  7.22            1         4
# 3       19467   22    Male     MCA     ME  7.78            2         4
# 4       23094   20  Female  B.Tech     ME  7.63            1         4
# 5        8710   20    Male     BCA    ECE  7.99            1         4
# 6       24363   21    Male     MCA    ECE  7.50            1         4
# 7       27448   19    Male  B.Tech     ME  8.00            0         4
# 8       23663   24    Male     BCA  Civil  6.24            0         3
# 9       39336   23    Male    B.Sc     ME  7.08            2         4
#
#    Coding_Skills  Communication_Skills  Aptitude_Test_Score  \
# 0              4                     6                   51
# 1              6                     8                   59
# ...

# %%
df.tail(10)
# Out:
#        Student_ID  Age  Gender  Degree Branch  CGPA  Internships  Projects  \
# 44990       36112   21    Male  B.Tech    CSE  5.04            1         3
# 44991        5529   18    Male    B.Sc     ME  8.21            0         4
# 44992       49628   22  Female     BCA     IT  6.26            0         3
# 44993       41608   24    Male    B.Sc    ECE  7.13            1         4
# 44994       17135   23    Male     BCA    ECE  6.30            0         4
# 44995        9362   20    Male     MCA  Civil  7.84            2         5
# 44996        8940   19  Female    B.Sc     ME  8.28            1         4
# 44997       13097   20  Female    B.Sc  Civil  8.88            0         4
# 44998       12958   24  Female     MCA    ECE  5.90            1         3
# 44999        9565   23  Female  B.Tech     ME  6.28            0         4
#
#        Coding_Skills  Communication_Skills  Aptitude_Test_Score  \
# 44990              4                     5                   38
# ...

# %%
#Displays total n.o of rows and columns
df.shape
# Out:
# (45000, 15)

# %%
#display only n.o of rows
rows,columns=df.shape
rows
# Out:
# 45000

# %%
#display only n.o of columns
rows,columns=df.shape
columns
# Out:
# 15

# %%
#display particular or individual feature
df['Gender']
# Out:
# 0        Female
# 1        Female
# 2          Male
# 3          Male
# 4        Female
#           ...
# 44995      Male
# 44996    Female
# 44997    Female
# 44998    Female
# 44999    Female
# Name: Gender, Length: 45000, dtype: object

# %%
df.columns
# Out:
# Index(['Student_ID', 'Age', 'Gender', 'Degree', 'Branch', 'CGPA',
#        'Internships', 'Projects', 'Coding_Skills', 'Communication_Skills',
#        'Aptitude_Test_Score', 'Soft_Skills_Rating', 'Certifications',
#        'Backlogs', 'Placement_Status'],
#       dtype='object')

# %%
df.dtypes
# Out:
# Student_ID                int64
# Age                       int64
# Gender                   object
# Degree                   object
# Branch                   object
# CGPA                    float64
# Internships               int64
# Projects                  int64
# Coding_Skills             int64
# Communication_Skills      int64
# Aptitude_Test_Score       int64
# Soft_Skills_Rating        int64
# Certifications            int64
# Backlogs                  int64
# Placement_Status         object
# dtype: object

# %%
#n.o of dtypes(features) are there
df.dtypes.value_counts()
# Out:
# int64      10
# object      4
# float64     1
# Name: count, dtype: int64

# %%
missing_data=pd.DataFrame({
    "Missing Values": df.isnull().sum(),
    "Percentage": (df.isnull().sum()/len(df))*100
})
missing_data
# Out:
#                       Missing Values  Percentage
# Student_ID                         0         0.0
# Age                                0         0.0
# Gender                             0         0.0
# Degree                             0         0.0
# Branch                             0         0.0
# CGPA                               0         0.0
# Internships                        0         0.0
# Projects                           0         0.0
# Coding_Skills                      0         0.0
# Communication_Skills               0         0.0
# Aptitude_Test_Score                0         0.0
# Soft_Skills_Rating                 0         0.0
# Certifications                     0         0.0
# Backlogs                           0         0.0
# Placement_Status                   0         0.0

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(10, 6))
sns.heatmap(df.isnull(), cbar=False, yticklabels=False, cmap="viridis")
plt.title("missing")
plt.show()

# %%
duplicate_rows = df[df.duplicated()]
print(f"Total duplicate rows detected: {len(duplicate_rows)}")
print(duplicate_rows)
print("-" * 40)
# Out:
# Total duplicate rows detected: 0
# Empty DataFrame
# Columns: [Student_ID, Age, Gender, Degree, Branch, CGPA, Internships, Projects, Coding_Skills, Communication_Skills, Aptitude_Test_Score, Soft_Skills_Rating, Certifications, Backlogs, Placement_Status]
# Index: []
# ----------------------------------------

# %%
df[df['Age'].isnull()]
# Out:
# Empty DataFrame
# Columns: [Student_ID, Age, Gender, Degree, Branch, CGPA, Internships, Projects, Coding_Skills, Communication_Skills, Aptitude_Test_Score, Soft_Skills_Rating, Certifications, Backlogs, Placement_Status]
# Index: []

# %%
#  Checking for Duplicates
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
#Remove Duplicates
df = df.drop_duplicates()
